# %%
import torch
import torch.nn as nn

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('NYCTaxiFares.csv')

# %%
df
# Out:
#                 pickup_datetime  fare_amount  fare_class  pickup_longitude  \
# 0       2010-04-19 08:17:56 UTC         6.50           0        -73.992365
# 1       2010-04-17 15:43:53 UTC         6.90           0        -73.990078
# 2       2010-04-17 11:23:26 UTC        10.10           1        -73.994149
# 3       2010-04-11 21:25:03 UTC         8.90           0        -73.990485
# 4       2010-04-17 02:19:01 UTC        19.70           1        -73.990976
# 5       2010-04-22 08:39:47 UTC         8.10           0        -73.980481
# 6       2010-04-23 19:27:00 UTC         4.90           0        -73.959535
# 7       2010-04-15 09:03:37 UTC         4.90           0        -74.002601
# 8       2010-04-20 08:58:00 UTC         2.90           0        -74.014005
# 9       2010-04-16 18:50:16 UTC         6.10           0        -73.977689
# 10      2010-04-22 22:26:23 UTC         7.30           0        -74.007913
# ...

# %%
row = 5
lon1,lat1,lon2, lat2 = df.iloc[row][3],df.loc[row][4],df.loc[row][5],df.loc[row][6]

# %%
lon1,lat1,lon2, lat2
# Out:
# (-73.98048100000001, 40.748995, -73.983508, 40.766459000000005)

# %%
from geopy.distance import geodesic

# %%
geodesic((lat1,lon1),(lat2,lon2)).kilometers
# Out:
# 1.9561356792610227

# %%
# %config Completer.use_jedi = False

# %%
def cal_dist(df):
    
    lon1,lat1,lon2,lat2 = df.pickup_longitude,df.pickup_latitude,df.dropoff_longitude,df.dropoff_latitude
    return geodesic((lat1,lon1),(lat2,lon2)).kilometers

# %%
df['distance']=df.apply(lambda x : cal_dist(x), axis=1)

# %%
df
# Out:
#                 pickup_datetime  fare_amount  fare_class  pickup_longitude  \
# 0       2010-04-19 08:17:56 UTC         6.50           0        -73.992365
# 1       2010-04-17 15:43:53 UTC         6.90           0        -73.990078
# 2       2010-04-17 11:23:26 UTC        10.10           1        -73.994149
# 3       2010-04-11 21:25:03 UTC         8.90           0        -73.990485
# 4       2010-04-17 02:19:01 UTC        19.70           1        -73.990976
# 5       2010-04-22 08:39:47 UTC         8.10           0        -73.980481
# 6       2010-04-23 19:27:00 UTC         4.90           0        -73.959535
# 7       2010-04-15 09:03:37 UTC         4.90           0        -74.002601
# 8       2010-04-20 08:58:00 UTC         2.90           0        -74.014005
# 9       2010-04-16 18:50:16 UTC         6.10           0        -73.977689
# 10      2010-04-22 22:26:23 UTC         7.30           0        -74.007913
# ...

# %%
torch.cuda.is_available()
# Out:
# True

# %%
torch.cuda.current_device()
# Out:
# 0

# %%
torch.cuda.get_device_name(0)
# Out:
# 'GeForce MX230'

# %%
torch.cuda.memory_allocated()
# Out:
# 0

# %%
torch.cuda.memory_cached()
# Out:
# 0

# %%
var = torch.tensor([1,2,3])

# %%
var.device
# Out:
# device(type='cpu')

# %%
# whenever call gpu, cuda is written in end
var_gpu = torch.tensor([3,4,5]).cuda()

# %%
var_gpu.device
# Out:
# device(type='cuda', index=0)

# %%
torch.cuda.memory_allocated()
# Out:
# 512
