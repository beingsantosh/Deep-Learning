# %%
# !pip install keras-tuner

# %%
import pandas as pd
from tensorflow.keras import layers
from tensorflow import keras
from kerastuner.tuners import RandomSearch
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split

# %%
# %config Completer.use_jedi = False

# %%
df = pd.read_csv('real_combine.csv')

# this dataset includes multiple independent variables and one dependent variable.
# It helps in predicting the air quality.

# %%
df.head()
# Out:
#    Unnamed: 0     T    TM   Tm     SLP     H   VV    V    VM      PM 2.5
# 0           0   7.4   9.8  4.8  1017.6  93.0  0.5  4.3   9.4  219.720833
# 1           1   7.8  12.7  4.4  1018.5  87.0  0.6  4.4  11.1  182.187500
# 2           2   6.7  13.4  2.4  1019.4  82.0  0.6  4.8  11.1  154.037500
# 3           3   8.6  15.5  3.3  1018.7  72.0  0.8  8.1  20.6  223.208333
# 4           4  12.4  20.9  4.4  1017.3  61.0  1.3  8.7  22.2  200.645833

# %%
X = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
def define_model(hp):
    model = Sequential()
    for i in range(hp.Int('num_layers', 2, 20)): 
        model.add(layers.Dense(units = hp.Int('units'+str(i),
                                             min_value=32,
                                             max_value=512,
                                             step=32),
                              activation= 'relu'))
        model.add(layers.Dense(1, activation = 'linear'))
        model.compile( 
            optimizer = keras.optimizers.Adam(
                    hp.Choice('learning_rate',[1e-2,1e-3,1e-4])),
            loss = 'mean_absolute_error',
            metrics = ['mean_absolute_error'])
        return model

# %% [markdown]
# ## List of hyperparameters in Deep neural network
#
# 1. No. of hidden layers
# 2. no. of neurons
# 3. learning rate

# %%
tuner = RandomSearch(
    define_model,
    objective = 'val_mean_absolute_error',
    max_trials=5,
    executions_per_trial=3,
    directory='project1',
    project_name='Air quality index')

# %%
tuner.search_space_summary()
# Out:
# [Search space summary]
#  |-Default search space size: 3
#  > num_layers (Int)
#  |-default: None
#  |-max_value: 20
#  |-min_value: 2
#  |-sampling: None
#  |-step: 1
#  > units0 (Int)
#  |-default: None
#  |-max_value: 512
#  |-min_value: 32
#  |-sampling: None
#  |-step: 32
#  > learning_rate (Choice)
#  |-default: 0.01
#  |-ordered: True
#  |-values: [0.01, 0.001, 0.0001]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
tuner.search(X_train, y_train, epochs = 5, validation_data = (X_test,y_test))
# Out:
# Epoch 1/5
# WARNING:tensorflow:Layer dense is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
#  1/23 [>.............................] - ETA: 0s - loss: 478.6945 - mean_absolute_error: 478.6945
# C:\Users\Mein Pc\.conda\envs\nlp_course\lib\site-packages\tensorflow\python\keras\callbacks.py:1291: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current, self.best):
# 23/23 [==============================] - 0s 5ms/step - loss: 330.5693 - mean_absolute_error: 330.5693 - val_loss: nan - val_mean_absolute_error: nan
# Epoch 2/5
# 23/23 [==============================] - ETA: 0s - loss: 134.4279 - mean_absolute_error: 134.427 - 0s 1ms/step - loss: 86.0871 - mean_absolute_error: 86.0871 - val_loss: nan - val_mean_absolute_error: nan
# Epoch 3/5
# 23/23 [==============================] - ETA: 0s - loss: 76.5779 - mean_absolute_error: 76.577 - 0s 1ms/step - loss: 72.2695 - mean_absolute_error: 72.2695 - val_loss: nan - val_mean_absolute_error: nan
# Epoch 4/5
# 23/23 [==============================] - ETA: 0s - loss: 56.1551 - mean_absolute_error: 56.155 - 0s 1ms/step - loss: 69.3540 - mean_absolute_error: 69.3540 - val_loss: nan - val_mean_absolute_error: nan
# Epoch 5/5
# 23/23 [==============================] - ETA: 0s - loss: 73.3235 - mean_absolute_error: 73.323 - 0s 1ms/step - loss: 68.1631 - mean_absolute_error: 68.1631 - val_loss: nan - val_mean_absolute_error: nan
# Epoch 1/5
# WARNING:tensorflow:Layer dense is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 23/23 [==============================] - ETA: 0s - loss: 71.4543 - mean_absolute_error: 71.454 - 0s 5ms/step - loss: 76.8747 - mean_absolute_error: 76.8747 - val_loss: nan - val_mean_absolute_error: nan
# Epoch 2/5
# 23/23 [==============================] - ETA: 0s - loss: 74.2241 - mean_absolute_error: 74.224 - 0s 1ms/step - loss: 66.9711 - mean_absolute_error: 66.9711 - val_loss: nan - val_mean_absolute_error: nan
# Epoch 3/5
# 23/23 [==============================] - ETA: 0s - loss: 52.9079 - mean_absolute_error: 52.907 - 0s 1ms/step - loss: 65.0401 - mean_absolute_error: 65.0401 - val_loss: nan - val_mean_absolute_error: nan
# Epoch 4/5
# 23/23 [==============================] - ETA: 0s - loss: 65.5571 - mean_absolute_error: 65.557 - 0s 1ms/step - loss: 64.1161 - mean_absolute_error: 64.1161 - val_loss: nan - val_mean_absolute_error: nan
# Epoch 5/5
# 23/23 [==============================] - ETA: 0s - loss: 69.3156 - mean_absolute_error: 69.315 - 0s 1ms/step - loss: 63.6780 - mean_absolute_error: 63.6780 - val_loss: nan - val_mean_absolute_error: nan
# Epoch 1/5
# WARNING:tensorflow:Layer dense is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 23/23 [==============================] - ETA: 0s - loss: 133.6906 - mean_absolute_error: 133.690 - 0s 5ms/step - loss: 83.2950 - mean_absolute_error: 83.2950 - val_loss: nan - val_mean_absolute_error: nan
# Epoch 2/5
# 23/23 [==============================] - ETA: 0s - loss:
- val_loss: nan - val_mean_absolute_error: nan
# Epoch 5/5
# 23/23 [==============================] - ETA: 0s - loss: 71.2976 - mean_absolute_error: 71.297 - 0s 1ms/step - loss: 57.4329 - mean_absolute_error: 57.4329 - val_loss: nan - val_mean_absolute_error: nan
# [Trial complete]
# [Trial summary]
#  |-Trial ID: bf37d13345400bdc4f4ed23046fdc647
#  |-Score: nan
#  |-Best step: None
#  > Hyperparameters:
#  |-learning_rate: 0.01
#  |-num_layers: 3
#  |-units0: 352
# Epoch 1/5
# WARNING:tensorflow:Layer dense is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 23/23 [==============================] - ETA: 0s - loss: 51.3063 - mean_absolute_error: 51.306 - 0s 5ms/step - loss: 66.5387 - mean_absolute_error: 66.5387 - val_loss: nan - val_mean_absolute_error: nan
# Epoch 2/5
# 23/23 [==============================] - ETA: 0s - loss: 77.7545 - mean_absolute_error: 77.754 - 0s 1ms/step - loss: 66.2090 - mean_absolute_error: 66.2090 - val_loss: nan - val_mean_absolute_error: nan
# Epoch 3/5
# 23/23 [==============================] - ETA: 0s - loss: 69.1592 - mean_absolute_error: 69.159 - 0s 1ms/step - loss: 64.8153 - mean_absolute_error: 64.8153 - val_loss: nan - val_mean_absolute_error: nan
# Epoch 4/5
# 23/23 [==============================] - ETA: 0s - loss: 64.7058 - mean_absolute_error: 64.705 - 0s 1ms/step - loss: 64.3540 - mean_absolute_error: 64.3540 - val_loss: nan - val_mean_absolute_error: nan
# Epoch 5/5
# 23/23 [==============================] - ETA: 0s - loss: 60.0694 - mean_absolute_error: 60.069 - 0s 1ms/step - loss: 63.8562 - mean_absolute_error: 63.8562 - val_loss: nan - val_mean_absolute_error: nan
# Epoch 1/5
# WARNING:tensorflow:Layer dense is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 23/23 [==============================] - ETA: 0s - loss: 57.8678 - mean_absolute_error: 57.867 - 0s 6ms/step - loss: 72.2060 - mean_absolute_error: 72.2060 - val_loss: nan - val_mean_absolute_error: nan
# Epoch 2/5
# 23/23 [==============================] - ETA: 0s - loss: 80.4165 - mean_absolute_error: 80.416 - 0s 1ms/step - loss: 65.9818 - mean_absolute_error: 65.9818 - val_loss: nan - val_mean_absolute_error: nan
# Epoch 3/5
# 23/23 [==============================] - ETA: 0s - loss: 74.3318 - mean_absolute_error: 74.331 - 0s 1ms/step - loss: 64.9789 - mean_absolute_error: 64.9789 - val_loss: nan - val_mean_absolute_error: nan
# Epoch 4/5
# 23/23 [==============================] - ETA: 0s - loss: 60.6360 - mean_absolute_error: 60.636 - 0s 1ms/step - loss: 65.0437 - mean_absolute_error: 65.0437 - val_loss: nan - val_mean_absolute_error: nan
# Epoch 5/5
# 23/23 [==============================] - ETA: 0s - loss: 61.5308 - mean_absolute_error: 61.530 - 0s 1ms/step - loss: 63.4778 - mean_absolute_error: 63.4778 - val_loss: nan - val_mean_absolute_error: nan
# Epoch 1/5
# WARNING:tensorflow:Layer dense is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 23/23 [==============================] - ETA: 0s - loss: 129.3793 - mean_absolute_error: 129.379 - 0s 6ms/step - loss: 90.9407 - mean_absolute_error: 90.9407 - val_loss: nan - val_mean_absolute_error: nan
# Epoch 2/5
# 23/23 [==============================] - ETA: 0s - loss: 81.6176 - mean_absolute_error: 81.617 - 0s 1ms/step - loss: 72.3374 - mean_absolute_error: 72.3374 - val_loss: nan - val_mean_absolute_error: nan
# Epoch 3/5
# 23/23 [==============================] - ETA: 0s - loss: 71.4909 - mean_absolute_error: 71.490 - 0s 1ms/step - loss: 65.9961 - mean_absolute_error: 65.9961 - val_loss: nan - val_mean_absolute_error: nan
# Epoch 4/5
# 23/23 [==============================] - ETA: 0s - loss: 49.7083 - mean_absolute_error: 49.708 - 0s 1ms/step - loss: 64.3534 - mean_absolute_error: 64.3534 - val_loss: nan - val_mean_absolute_error: nan
# Epoch 5/5
# 23/23 [==============================] - ETA: 0s - loss: 75.4368 - mean_absolute_error: 75.436 - 0s 1ms/step - loss: 63.8516 - mean_absolute_error: 63.8516 - val_loss: nan - val_mean_absolute_error: nan
# [Trial complete]
# [Trial summary]
#  |-Trial ID: 0103c6220bd52303447eaf9c78c10763
#  |-Score: nan
#  |-Best step: None
#  > Hyperparameters:
#  |-learning_rate: 0.001
#  |-num_layers: 13
#  |-units0: 32
# INFO:tensorflow:Oracle triggered exit

# %%
tuner.results_summary()
# Out:
# [Results summary]
#  |-Results in project1\Air quality index
#  |-Showing 10 best trials
#  |-Objective(name='val_mean_absolute_error', direction='min')
# [Trial summary]
#  |-Trial ID: 49ce9a954a68e62ab4ee872dc4153cfd
#  |-Score: nan
#  |-Best step: None
#  > Hyperparameters:
#  |-learning_rate: 0.001
#  |-num_layers: 14
#  |-units0: 64
# [Trial summary]
#  |-Trial ID: a00a6376b4d9a0ccfe247a5b8f50baa4
#  |-Score: nan
#  |-Best step: None
#  > Hyperparameters:
#  |-learning_rate: 0.01
#  |-num_layers: 3
#  |-units0: 96
# [Trial summary]
#  |-Trial ID: 402d9e082cd065a715f44be1c4204043
#  |-Score: nan
#  |-Best step: None
#  > Hyperparameters:
#  |-learning_rate: 0.01
#  |-num_layers: 19
#  |-units0: 384
# [Trial summary]
#  |-Trial ID: bf37d13345400bdc4f4ed23046fdc647
#  |-Score: nan
#  |-Best step: None
#  > Hyperparameters:
#  |-learning_rate: 0.01
#  |-num_layers: 3
#  |-units0: 352
# [Trial summary]
#  |-Trial ID: 0103c6220bd52303447eaf9c78c10763
#  |-Score: nan
#  |-Best step: None
#  > Hyperparameters:
#  |-learning_rate: 0.001
#  |-num_layers: 13
#  |-units0: 32
